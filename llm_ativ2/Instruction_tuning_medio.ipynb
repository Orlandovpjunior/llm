# %% [markdown]
# # Laboratório: Fine-Tuning de LLMs para Instruction Following
# Configuração do ambiente e verificação de versões.

# %%
# !pip install datasets pandas psutil requests tqdm tiktoken torch matplotlib llms-from-scratch

from importlib.metadata import version
import torch
import random
import time
import json
import os
import requests
import re
import numpy as np
from tqdm import tqdm
import pandas as pd
from datasets import load_dataset
import tiktoken
from torch.utils.data import Dataset, DataLoader
from functools import partial

# Importações do repositório
from llms_from_scratch.ch04 import GPTModel
from llms_from_scratch.ch05 import (
    download_and_load_gpt2,
    load_weights_into_gpt,
    generate,
    text_to_token_ids,
    token_ids_to_text,
    plot_losses,
    calc_loss_loader,
    train_model_simple
)

torch.manual_seed(123)
random.seed(123)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")
# Out:
# Requirement already satisfied: datasets in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (4.5.0)
# Requirement already satisfied: pandas in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (3.0.1)
# Requirement already satisfied: psutil in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (7.2.2)
# Requirement already satisfied: requests in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (2.32.5)
# Requirement already satisfied: tqdm in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (4.67.3)
# Requirement already satisfied: tiktoken in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (0.12.0)
# Requirement already satisfied: torch in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (2.10.0)
# Requirement already satisfied: matplotlib in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (3.10.8)
# Requirement already satisfied: llms-from-scratch in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (1.0.18)
# Requirement already satisfied: filelock in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from datasets) (3.24.2)
# Requirement already satisfied: numpy>=1.17 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from datasets) (2.4.2)
# Requirement already satisfied: pyarrow>=21.0.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from datasets) (23.0.1)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from datasets) (0.4.0)
# Requirement already satisfied: httpx<1.0.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from datasets) (0.28.1)
# Requirement already satisfied: xxhash in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from datasets) (0.70.18)
# Requirement already satisfied: fsspec<=2025.10.0,>=2023.1.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2025.10.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.25.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from datasets) (1.4.1)
# Requirement already satisfied: packaging in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from datasets) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from datasets) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (3.13.3)
# Requirement already satisfied: anyio in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (4.12.1)
# Requirement already satisfied: certifi in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from httpx<1.0.0->datasets) (3.11)
# Requirement already satisfied: h11>=0.16 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.2.0)
# Requirement already satisfied: shellingham in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (1.5.4)
# Requirement already satisfied: typer-slim in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (0.24.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from huggingface-hub<2.0,>=0.25.0->datasets) (4.15.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from requests) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from requests) (2.6.3)
# Requirement already satisfied: regex>=2022.1.18 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from tiktoken) (2026.1.15)
# Requirement already satisfied: sympy>=1.13.3 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from torch) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from torch) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from torch) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from torch) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from torch) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from torch) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from torch) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from cuda-bindings==12.9.4->torch) (1.3.4)
# Requirement already satisfied: contourpy>=1.0.1 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: tensorflow>=2.18.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from llms-from-scratch) (2.20.0)
# Requirement already satisfied: jupyterlab>=4.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from llms-from-scratch) (4.5.4)
# Requirement already satisfied: pip>=25.0.1 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from llms-from-scratch) (26.0.1)
# Requirement already satisfied: pytest>=8.3.5 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from llms-from-scratch) (9.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: async-lru>=1.0.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from jupyterlab>=4.0->llms-from-scratch) (2.1.0)
# Requirement already satisfied: ipykernel!=6.30.0,>=6.5.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from jupyterlab>=4.0->llms-from-scratch) (7.2.0)
# Requirement already satisfied: jupyter-core in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from jupyterlab>=4.0->llms-from-scratch) (5.9.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from jupyterlab>=4.0->llms-from-scratch) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from jupyterlab>=4.0->llms-from-scratch) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from jupyterlab>=4.0->llms-from-scratch) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from jupyterlab>=4.0->llms-from-scratch) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from jupyterlab>=4.0->llms-from-scratch) (80.10.2)
# Requirement already satisfied: tornado>=6.2.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from jupyterlab>=4.0->llms-from-scratch) (6.5.4)
# Requirement already satisfied: traitlets in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from jupyterlab>=4.0->llms-from-scratch) (5.14.3)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.0->llms-from-scratch) (25.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.0->llms-from-scratch) (8.8.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.0->llms-from-scratch) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.0->llms-from-scratch) (0.5.4)
# Requirement already satisfied: nbconvert>=6.4.4 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.0->llms-from-scratch) (7.17.0)
# Requirement already satisfied: nbformat>=5.3.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.0->llms-from-scratch) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.0->llms-from-scratch) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.0->llms-from-scratch) (0.24.1)
# Requirement already satisfied: pyzmq>=24 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.0->llms-from-scratch) (27.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.0->llms-from-scratch) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.0->llms-from-scratch) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.0->llms-from-scratch) (1.9.0)
# Requirement already satisfied: babel>=2.10 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab>=4.0->llms-from-scratch) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab>=4.0->llms-from-scratch) (0.13.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab>=4.0->llms-from-scratch) (4.26.0)
# Requirement already satisfied: argon2-cffi-bindings in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab>=4.0->llms-from-scratch) (25.1.0)
# Requirement already satisfied: comm>=0.1.1 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.0->llms-from-scratch) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.0->llms-from-scratch) (1.8.20)
# Requirement already satisfied: ipython>=7.23.1 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.0->llms-from-scratch) (9.10.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.0->llms-from-scratch) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.0->llms-from-scratch) (1.6.0)
# Requirement already satisfied: decorator>=4.3.2 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.0->llms-from-scratch) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.0->llms-from-scratch) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.0->llms-from-scratch) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.0->llms-from-scratch) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.0->llms-from-scratch) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.0->llms-from-scratch) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.0->llms-from-scratch) (0.6.3)
# Requirement already satisfied: wcwidth in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.0->llms-from-scratch) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from jedi>=0.18.1->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.0->llms-from-scratch) (0.8.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab>=4.0->llms-from-scratch) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab>=4.0->llms-from-scratch) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab>=4.0->llms-from-scratch) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from jupyter-core->jupyterlab>=4.0->llms-from-scratch) (4.9.2)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.0->llms-from-scratch) (4.0.0)
# Requirement already satisfied: rfc3339-validator in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.0->llms-from-scratch) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.0->llms-from-scratch) (0.1.1)
# Requirement already satisfied: fqdn in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.0->llms-from-scratch) (1.5.1)
# Requirement already satisfied: isoduration in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.0->llms-from-scratch) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.0->llms-from-scratch) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.0->llms-from-scratch) (1.1.0)
# Requirement already satisfied: uri-template in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.0->llms-from-scratch) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.0->llms-from-scratch) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=4.0->llms-from-scratch) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=4.0->llms-from-scratch) (6.3.0)
# Requirement already satisfied: defusedxml in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=4.0->llms-from-scratch) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=4.0->llms-from-scratch) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=4.0->llms-from-scratch) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=4.0->llms-from-scratch) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=4.0->llms-from-scratch) (1.5.1)
# Requirement already satisfied: webencodings in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=4.0->llms-from-scratch) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=4.0->llms-from-scratch) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.0->llms-from-scratch) (2.21.2)
# Requirement already satisfied: ptyprocess>=0.5 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.0->llms-from-scratch) (0.7.0)
# Requirement already satisfied: iniconfig>=1.0.1 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from pytest>=8.3.5->llms-from-scratch) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from pytest>=8.3.5->llms-from-scratch) (1.6.0)
# Requirement already satisfied: six>=1.5 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: lark>=1.2.2 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.0->llms-from-scratch) (1.3.1)
# Requirement already satisfied: executing>=1.2.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.0->llms-from-scratch) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.0->llms-from-scratch) (3.0.1)
# Requirement already satisfied: pure-eval in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.0->llms-from-scratch) (0.2.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from tensorflow>=2.18.0->llms-from-scratch) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from tensorflow>=2.18.0->llms-from-scratch) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from tensorflow>=2.18.0->llms-from-scratch) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from tensorflow>=2.18.0->llms-from-scratch) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from tensorflow>=2.18.0->llms-from-scratch) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from tensorflow>=2.18.0->llms-from-scratch) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from tensorflow>=2.18.0->llms-from-scratch) (3.4.0)
# Requirement already satisfied: protobuf>=5.28.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from tensorflow>=2.18.0->llms-from-scratch) (6.33.5)
# Requirement already satisfied: termcolor>=1.1.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from tensorflow>=2.18.0->llms-from-scratch) (3.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from tensorflow>=2.18.0->llms-from-scratch) (2.1.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from tensorflow>=2.18.0->llms-from-scratch) (1.78.0)
# Requirement already satisfied: tensorboard~=2.20.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from tensorflow>=2.18.0->llms-from-scratch) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from tensorflow>=2.18.0->llms-from-scratch) (3.13.2)
# Requirement already satisfied: h5py>=3.11.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from tensorflow>=2.18.0->llms-from-scratch) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from tensorflow>=2.18.0->llms-from-scratch) (0.5.4)
# Requirement already satisfied: markdown>=2.6.8 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from tensorboard~=2.20.0->tensorflow>=2.18.0->llms-from-scratch) (3.10.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from tensorboard~=2.20.0->tensorflow>=2.18.0->llms-from-scratch) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from tensorboard~=2.20.0->tensorflow>=2.18.0->llms-from-scratch) (3.1.5)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow>=2.18.0->llms-from-scratch) (0.46.3)
# Requirement already satisfied: rich in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from keras>=3.10.0->tensorflow>=2.18.0->llms-from-scratch) (14.3.2)
# Requirement already satisfied: namex in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from keras>=3.10.0->tensorflow>=2.18.0->llms-from-scratch) (0.1.0)
# Requirement already satisfied: optree in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from keras>=3.10.0->tensorflow>=2.18.0->llms-from-scratch) (0.18.0)
# Requirement already satisfied: cffi>=1.0.1 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab>=4.0->llms-from-scratch) (2.0.0)
# Requirement already satisfied: pycparser in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab>=4.0->llms-from-scratch) (3.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=4.0->llms-from-scratch) (2.8.3)
# Requirement already satisfied: arrow>=0.15.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.0->llms-from-scratch) (1.4.0)
# Requirement already satisfied: tzdata in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.0->llms-from-scratch) (2025.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from rich->keras>=3.10.0->tensorflow>=2.18.0->llms-from-scratch) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow>=2.18.0->llms-from-scratch) (0.1.2)
# Requirement already satisfied: typer>=0.24.0 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (0.24.0)
# Requirement already satisfied: click>=8.2.1 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from typer>=0.24.0->typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (8.3.1)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/orlandojunior/miniconda3/envs/llm-scratch/lib/python3.11/site-packages (from typer>=0.24.0->typer-slim->huggingface-hub<2.0,>=0.25.0->datasets) (0.0.4)
# Device: cuda

# %% [markdown]
# ## 1. Construção do Dataset de Instruções
# Carregando o AG News, formatando para instruções

# %%
dataset = load_dataset("ag_news")
df = pd.DataFrame(dataset['train']).sample(2000, random_state=42)
label_map = {0: "Mundo", 1: "Esportes", 2: "Negócios", 3: "Ciência/Tecnologia"}

meu_dataset = []
for _, row in df.iterrows():
    if len(row['text']) > 50:
        meu_dataset.append({
            "instruction": "Classifique o texto da notícia abaixo em uma das seguintes categorias: Mundo, Esportes, Negócios ou Ciência/Tecnologia.",
            "input": row['text'],
            "output": label_map[row['label']]
        })

random.shuffle(meu_dataset)
total = len(meu_dataset)
train_data_medio = meu_dataset[:int(total * 0.8)]
val_data = meu_dataset[int(total * 0.8):int(total * 0.9)]
test_data = meu_dataset[int(total * 0.9):]

print(f"Treino Médio: {len(train_data_medio)} | Val: {len(val_data)} | Teste: {len(test_data)}")

def format_input(entry):
    instruction_text = (
        f"Abaixo está uma instrução que descreve uma tarefa. "
        f"Escreva uma resposta que conclua a solicitação adequadamente."
        f"\n\n### Instrução:\n{entry['instruction']}"
    )
    input_text = f"\n\n### Entrada:\n{entry['input']}" if entry.get("input") else ""
    return instruction_text + input_text

print("\nExemplo formatado:")
print(format_input(train_data_medio[0]))
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Generating train split: 100%|██████████| 120000/120000 [00:00<00:00, 1363831.28 examples/s]
# Generating test split: 100%|██████████| 7600/7600 [00:00<00:00, 1654386.05 examples/s]
# Treino Médio: 1600 | Val: 200 | Teste: 200
#
# Exemplo formatado:
# Abaixo está uma instrução que descreve uma tarefa. Escreva uma resposta que conclua a solicitação adequadamente.
#
# ### Instrução:
# Classifique o texto da notícia abaixo em uma das seguintes categorias: Mundo, Esportes, Negócios ou Ciência/Tecnologia.
#
# ### Entrada:
# Spam enforcers urged to work together Johannesburg, 12 October 2004 - International consumer law enforcers from 29 countries were yesterday urged to work together to combat the growing threat of spam.

# %% [markdown]
# ## 2. Preparação dos DataLoaders (Analítico)
# Usando a custom_collate_fn do Cap 07 e verificando o formato dos tensores gerados para garantir que o padding e a máscara (-100) funcionem.

# %%
tokenizer = tiktoken.get_encoding("gpt2")

class InstructionDataset(Dataset):
    def __init__(self, data, tokenizer):
        self.data = data
        self.encoded_texts = []
        for entry in data:
            instruction_plus_input = format_input(entry)
            response_text = f"\n\n### Resposta:\n{entry['output']}"
            full_text = instruction_plus_input + response_text
            self.encoded_texts.append(tokenizer.encode(full_text))
    def __getitem__(self, index): return self.encoded_texts[index]
    def __len__(self): return len(self.data)

def custom_collate_fn(batch, pad_token_id=50256, ignore_index=-100, allowed_max_length=None, device="cpu"):
    batch_max_length = max(len(item)+1 for item in batch)
    inputs_lst, targets_lst = [], []
    for item in batch:
        new_item = item.copy()
        new_item += [pad_token_id]
        padded = new_item + [pad_token_id] * (batch_max_length - len(new_item))
        inputs = torch.tensor(padded[:-1])
        targets = torch.tensor(padded[1:])
        mask = targets == pad_token_id
        indices = torch.nonzero(mask).squeeze()
        if indices.numel() > 1:
            targets[indices[1:]] = ignore_index
        if allowed_max_length is not None:
            inputs = inputs[:allowed_max_length]
            targets = targets[:allowed_max_length]
        inputs_lst.append(inputs)
        targets_lst.append(targets)
    return torch.stack(inputs_lst).to(device), torch.stack(targets_lst).to(device)

# %% [markdown]
# ## 2.1 Creating data loaders for an instruction dataset
# Instanciando os lotes e inspecionando visualmente as matrizes para garantir que o padding e a máscara (-100) foram aplicados com sucesso.

# %%
customized_collate_fn = partial(custom_collate_fn, device=device, allowed_max_length=256)
batch_size = 8

train_dataset_medio = InstructionDataset(train_data_medio, tokenizer)
train_loader_medio = DataLoader(train_dataset_medio, batch_size=batch_size, collate_fn=customized_collate_fn, shuffle=True, drop_last=True)

val_dataset = InstructionDataset(val_data, tokenizer)
val_loader = DataLoader(val_dataset, batch_size=batch_size, collate_fn=customized_collate_fn, shuffle=False)

print("Análise das dimensões do Train loader:")
for inputs, targets in train_loader_medio:
    print(inputs.shape, targets.shape)
    break

inputs, targets = next(iter(train_loader_medio))
print("\nPrimeira matriz de Entrada (Inputs) - Note os tokens 50256:")
print(inputs[0])
print("\nPrimeira matriz de Alvo (Targets) - Note os placeholders -100:")
print(targets[0])
# Out:
# Análise das dimensões do Train loader:
# torch.Size([8, 175]) torch.Size([8, 175])
#
# Primeira matriz de Entrada (Inputs) - Note os tokens 50256:
# tensor([ 4826,    64,   844,    78,  1556,  6557,   334,  2611,   916,   622,
#         16175, 28749,  8358,  1715, 36955,   334,  2611,   256,   533, 13331,
#            13, 16319,   260,  6862,   334,  2611,  1217, 39818,  8358,   369,
#           565,  6413,   257, 25063,    64, 16175, 28749,  9939,   324,  3263,
#            68,    13,   198,   198, 21017,  2262,   622, 16175, 28749,    25,
#           198,  9487,   361,  2350,   267,  2420,    78, 12379,   407,  8836,
#         33743,   450,    64,   844,    78,   795,   334,  2611,   288,   292,
#           384,  5162,   600,   274, 17851,  4448,    25, 33324,    78,    11,
#          8678,   634,   274,    11, 13496, 10205,   979,   418,   267,    84,
#         37685, 25792, 10782,   544,    14,    51,   721,    77,   928,   544,
#            13,   198,   198, 21017,  7232,    81,  4763,    25,   198,  7447,
#            71,   293,  3756, 18722,   287, 18841,   290, 28052, 14466, 17321,
#          2520,  3334,  3961,  9669,   290, 13126, 10654,  4705,  2441,    71,
#           293,   318,   783,   257, 13430,   379, 11131,  2059,    11,   810,
#           262,   718,    12,  5898,    12,    23,    12,  8589,  2651,   373,
#          3756,   262,  1450,   338,  9669,  1074,   287,  3405,  9969,   290,
#         28052,   290,   373,  1218,   287,  9689,   832,  2237,  1830,    13,
#           198,   198, 21017,  1874,  7353,    64,    25,   198, 23041,   634,
#           274, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#         50256, 50256], device='cuda:0')
#
# Primeira matriz de Alvo (Targets) - Note os placeholders -100:
# tensor([   64,   844,    78,  1556,  6557,   334,  2611,   916,   622, 16175,
#         28749,  8358,  1715, 36955,   334,  2611,   256,   533, 13331,    13,
#         16319,   260,  6862,   334,  2611,  1217, 39818,  8358,   369,   565,
#          6413,   257, 25063,    64, 16175, 28749,  9939,   324,  3263,    68,
#            13,   198,   198, 21017,  2262,   622, 16175, 28749,    25,   198,
#          9487,   361,  2350,   267,  2420,    78, 12379,   407,  8836, 33743,
#           450,    64,   844,    78,   795,   334,  2611,   288,   292,   384,
#          5162,   600,   274, 17851,  4448,    25, 33324,    78,    11,  8678,
#           634,   274,    11, 13496, 10205,   979,   418,   267,    84, 37685,
#         25792, 10782,   544,    14,    51,   721,    77,   928,   544,    13,
#           198,   198, 21017,  7232,    81,  4763,    25,   198,  7447,    71,
#           293,  3756, 18722,   287, 18841,   290, 28052, 14466, 17321,  2520,
#          3334,  3961,  9669,   290, 13126, 10654,  4705,  2441,    71,   293,
#           318,   783,   257, 13430,   379, 11131,  2059,    11,   810,   262,
#           718,    12,  5898,    12,    23,    12,  8589,  2651,   373,  3756,
#           262,  1450,   338,  9669,  1074,   287,  3405,  9969,   290, 28052,
#           290,   373,  1218,   287,  9689,   832,  2237,  1830,    13,   198,
#           198, 21017,  1874,  7353,    64,    25,   198, 23041,   634,   274,
#         50256,  -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,  -100,
#          -100,  -100], device='cuda:0')

# %% [markdown]
# ## 3. Avaliação Baseline (Modelo Não Treinado)
# Aqui geramos as respostas de controle. Como o modelo não viu o dataset estruturado, ele tende a repetir as instruções.

# %%
BASE_CONFIG = {
    "vocab_size": 50257, "context_length": 1024, "drop_rate": 0.0, "qkv_bias": True,
    "emb_dim": 1024, "n_layers": 24, "n_heads": 16
}
settings, params = download_and_load_gpt2(model_size="355M", models_dir="gpt2")

model = GPTModel(BASE_CONFIG)
load_weights_into_gpt(model, params)
model.to(device)
model.eval()

print("Gerando respostas BASELINE (antes do Fine-Tuning)...")
for i, entry in tqdm(enumerate(test_data), total=len(test_data)):
    input_text = format_input(entry)
    token_ids = generate(
        model=model, idx=text_to_token_ids(input_text, tokenizer).to(device),
        max_new_tokens=25, context_size=BASE_CONFIG["context_length"], eos_id=50256
    )
    generated_text = token_ids_to_text(token_ids, tokenizer)
    test_data[i]["model_base_response"] = generated_text[len(input_text):].replace("### Resposta:", "").strip()
# Out:
# 2026-02-20 18:04:11.232519: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-20 18:04:11.979440: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-02-20 18:04:14.019885: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# File already exists and is up-to-date: gpt2/355M/checkpoint
# File already exists and is up-to-date: gpt2/355M/encoder.json
# File already exists and is up-to-date: gpt2/355M/hparams.json
# File already exists and is up-to-date: gpt2/355M/model.ckpt.data-00000-of-00001
# File already exists and is up-to-date: gpt2/355M/model.ckpt.index
# File already exists and is up-to-date: gpt2/355M/model.ckpt.meta
# File already exists and is up-to-date: gpt2/355M/vocab.bpe
# Gerando respostas BASELINE (antes do Fine-Tuning)...
# 100%|██████████| 200/200 [02:47<00:00,  1.19it/s]

# %% [markdown]
# ## 4. Treinamento Fine-Tuning (Datset Médio) e Análise de Loss
# Cálculo da Initial Loss, seguido pelo treinamento do modelo e plotagem das curvas de perda.

# %%
torch.manual_seed(123)

with torch.no_grad():
    train_loss = calc_loss_loader(train_loader_medio, model, device, num_batches=5)
    val_loss = calc_loss_loader(val_loader, model, device, num_batches=5)

print("Perda Inicial (Training loss):", train_loss)
print("Perda Inicial (Validation loss):", val_loss)

optimizer = torch.optim.AdamW(model.parameters(), lr=0.00005, weight_decay=0.1)
num_epochs = 2
start_time = time.time()

print("\nIniciando Treinamento GPT-2 (Dataset Médio)...")
train_losses, val_losses, tokens_seen = train_model_simple(
    model, train_loader_medio, val_loader, optimizer, device,
    num_epochs=num_epochs, eval_freq=5, eval_iter=5,
    start_context=format_input(val_data[0]), tokenizer=tokenizer
)
print(f"Treino concluído em {(time.time() - start_time) / 60:.2f} minutos.")

epochs_tensor = torch.linspace(0, num_epochs, len(train_losses))
plot_losses(epochs_tensor, tokens_seen, train_losses, val_losses)
# Out:
# Perda Inicial (Training loss): 4.04389967918396
# Perda Inicial (Validation loss): 3.9683649063110353
#
# Iniciando Treinamento GPT-2 (Dataset Médio)...
# Ep 1 (Step 000000): Train loss 3.124, Val loss 3.067
# Ep 1 (Step 000005): Train loss 1.276, Val loss 1.375
# Ep 1 (Step 000010): Train loss 1.088, Val loss 1.146
# Ep 1 (Step 000015): Train loss 1.048, Val loss 1.111
# Ep 1 (Step 000020): Train loss 0.958, Val loss 1.089
# Ep 1 (Step 000025): Train loss 0.962, Val loss 1.069
# Ep 1 (Step 000030): Train loss 0.957, Val loss 1.057
# Ep 1 (Step 000035): Train loss 0.949, Val loss 1.046
# Ep 1 (Step 000040): Train loss 0.989, Val loss 1.039
# Ep 1 (Step 000045): Train loss 0.976, Val loss 1.029
# Ep 1 (Step 000050): Train loss 0.914, Val loss 1.021
# Ep 1 (Step 000055): Train loss 0.905, Val loss 1.012
# Ep 1 (Step 000060): Train loss 0.862, Val loss 1.006
# Ep 1 (Step 000065): Train loss 0.907, Val loss 1.001
# Ep 1 (Step 000070): Train loss 0.932, Val loss 1.000
# Ep 1 (Step 000075): Train loss 0.910, Val loss 0.997
# Ep 1 (Step 000080): Train loss 0.868, Val loss 0.997
# Ep 1 (Step 000085): Train loss 0.913, Val loss 0.994
# Ep 1 (Step 000090): Train loss 0.843, Val loss 0.989
# Ep 1 (Step 000095): Train loss 0.884, Val loss 0.986
# Ep 1 (Step 000100): Train loss 0.828, Val loss 0.985
# Ep 1 (Step 000105): Train loss 0.794, Val loss 0.984
# Ep 1 (Step 000110): Train loss 0.867, Val loss 0.983
# Ep 1 (Step 000115): Train loss 0.778, Val loss 0.982
# Ep 1 (Step 000120): Train loss 0.840, Val loss 0.980
# Ep 1 (Step 000125): Train loss 0.878, Val loss 0.975
# Ep 1 (Step 000130): Train loss 0.846, Val loss 0.968
# Ep 1 (Step 000135): Train loss 0.850, Val loss 0.962
# Ep 1 (Step 000140): Train loss 0.769, Val loss 0.957
# Ep 1 (Step 000145): Train loss 0.820, Val loss 0.954
# Ep 1 (Step 000150): Train loss 0.800, Val loss 0.952
# Ep 1 (Step 000155): Train loss 0.807, Val loss 0.950
# Ep 1 (Step 000160): Train loss 0.755, Val loss 0.950
# Ep 1 (Step 000165): Train loss 0.858, Val loss 0.951
# Ep 1 (Step 000170): Train loss 0.769, Val loss 0.949
# Ep 1 (Step 000175): Train loss 0.787, Val loss 0.950
# Ep 1 (Step 000180): Train loss 0.839, Val loss 0.947
# Ep 1 (Step 000185): Train loss 0.769, Val loss 0.943
# Ep 1 (Step 000190): Train loss 0.768, Val loss 0.941
# Ep 1 (Step 000195): Train loss 0.793, Val loss 0.941
# Abaixo está uma instrução que descreve uma tarefa. Escreva uma resposta que conclua a solicitação adequadamente.  ### Instrução: Classifique o texto da notícia abaixo em uma das seguintes categorias: Mundo, Esportes, Negócios ou Ciência/Tecnologia.  ### Entrada: Arabs: Terror War Has Spread Instability (AP) AP - Victims of the Sept. 11 attacks were mourned worldwide Saturday, but in the Middle East, amid sympathy for the dead, Arabs said Washington's support for Israel and the war on terror launched in the aftermath of the World Trade Center's collapse have only fueled anger and violence.  ### Resposta: Mundo<|endoftext|>The first time I saw the movie, I was a little confused. I thought it was a movie about a guy who is a little bit of a geek. I thought it was a movie about
# Ep 2 (Step 000200): Train loss 0.762, Val loss 0.941
# Ep 2 (Step 000205): Train loss 0.714, Val loss 0.942
# Ep 2 (Step 000210): Train loss 0.761, Val loss 0.953
# Ep 2 (Step 000215): Train loss 0.682, Val loss 0.960
# Ep 2 (Step 000220): Train loss 0.738, Val loss 0.961
# Ep 2 (Step 000225): Train loss 0.705, Val loss 0.963
# Ep 2 (Step 000230): Train loss 0.745, Val loss 0.962
# Ep 2 (Step 000235): Train loss 0.673, Val loss 0.963
# Ep 2 (Step 000240): Train loss 0.655, Val loss 0.962
# Ep 2 (Step 000245): Train loss 0.713, Val loss 0.962
# Ep 2 (Step 000250): Train loss 0.673, Val loss 0.962
# Ep 2 (Step 000255): Train loss 0.653, Val loss 0.962
# Ep 2 (Step 000260): Train loss 0.702, Val loss 0.963
# Ep 2 (Step 000265): Train loss 0.733, Val loss 0.968
# Ep 2 (Step 000270): Train loss 0.707, Val loss 0.968
# Ep 2 (Step 000275): Train loss 0.652, Val loss 0.961
# Ep 2 (Step 000280): Train loss 0.656, Val loss 0.958
# Ep 2 (Step 000285): Train loss 0.630, Val loss 0.960
# Ep 2 (Step 000290): Train loss 0.607, Val loss 0.962
# Ep 2 (Step 000295): Train loss 0.680, Val loss 0.963
# Ep 2 (Step 000300): Train loss 0.673, Val loss 0.966
# Ep 2 (Step 000305): Train loss 0.674, Val loss 0.964
# Ep 2 (Step 000310): Train loss 0.650, Val loss 0.966
# Ep 2 (Step 000315): Train loss 0.602, Val loss 0.965
# Ep 2 (Step 000320): Train loss 0.591, Val loss 0.963
# Ep 2 (Step 000325): Train loss 0.625, Val loss 0.961
# Ep 2 (Step 000330): Train loss 0.595, Val loss 0.960
# Ep 2 (Step 000335): Train loss 0.596, Val loss 0.959
# Ep 2 (Step 000340): Train loss 0.626, Val loss 0.959
# Ep 2 (Step 000345): Train loss 0.582, Val loss 0.956
# Ep 2 (Step 000350): Train loss 0.609, Val loss 0.953
# Ep 2 (Step 000355): Train loss 0.615, Val loss 0.953
# Ep 2 (Step 000360): Train loss 0.545, Val loss 0.955
# Ep 2 (Step 000365): Train loss 0.602, Val loss 0.955
# Ep 2 (Step 000370): Train loss 0.575, Val loss 0.956
# Ep 2 (Step 000375): Train loss 0.569, Val loss 0.956
# Ep 2 (Step 000380): Train loss 0.553, Val loss 0.956
# Ep 2 (Step 000385): Train loss 0.541, Val loss 0.957
# Ep 2 (Step 000390): Train loss 0.508, Val loss 0.957
# Ep 2 (Step 000395): Train loss 0.571, Val loss 0.953
# Abaixo está uma instrução que descreve uma tarefa. Escreva uma resposta que conclua a solicitação adequadamente.  ### Instrução: Classifique o texto da notícia abaixo em uma das seguintes categorias: Mundo, Esportes, Negócios ou Ciência/Tecnologia.  ### Entrada: Arabs: Terror War Has Spread Instability (AP) AP - Victims of the Sept. 11 attacks were mourned worldwide Saturday, but in the Middle East, amid sympathy for the dead, Arabs said Washington's support for Israel and the war on terror launched in the aftermath of the World Trade Center's collapse have only fueled anger and violence.  ### Resposta: Mundo<|endoftext|>The following is a guest post by Dr. Michael Grebb, a professor of medicine at the University of Pittsburgh Medical Center.  In a recent study, researchers at the University of Pittsburgh Medical
# Treino concluído em 21.31 minutos.

# %% [markdown]
# ## 5. Gerando as Respostas Pós-Treino e Salvando o Modelo
# Geração das respostas do modelo adaptado para comparativo com o Baseline.

# %%
import json
import torch

model.eval()

print("--- Avaliação Visual (3 exemplos) ---\n")
torch.manual_seed(123)

for entry in test_data[:3]:
    input_text = format_input(entry)

    token_ids = generate(
        model=model,
        idx=text_to_token_ids(input_text, tokenizer).to(device),
        max_new_tokens=256,
        context_size=BASE_CONFIG["context_length"],
        eos_id=50256
    )
    generated_text = token_ids_to_text(token_ids, tokenizer)
    response_text = (
        generated_text[len(input_text):]
        .replace("### Resposta:", "")
        .strip()
    )

    print(input_text)
    print(f"\nCorrect response:\n>> {entry['output']}")
    print(f"\nModel response:\n>> {response_text.strip()}")
    print("-------------------------------------")

print("\nA gerar respostas FINE-TUNED para todo o conjunto de teste...")

for i, entry in tqdm(enumerate(test_data), total=len(test_data)):
    input_text = format_input(entry)

    token_ids = generate(
        model=model,
        idx=text_to_token_ids(input_text, tokenizer).to(device),
        max_new_tokens=25, # Reduzido para 25 aqui apenas para gerar rápido
        context_size=BASE_CONFIG["context_length"],
        eos_id=50256
    )
    generated_text = token_ids_to_text(token_ids, tokenizer)
    response_text = generated_text[len(input_text):].replace("### Resposta:", "").strip()

    test_data[i]["model_ft_medio_response"] = response_text

# Guardar o JSON com as respostas
with open("instruction-data-with-response.json", "w", encoding="utf-8") as file:
    json.dump(test_data, file, indent=4, ensure_ascii=False)

# Guardar os pesos do modelo treinado
torch.save(model.state_dict(), "gpt2-medium-ft-medio.pth")

print("\nConcluído! Dados guardados em 'instruction-data-with-response.json'")
print("Pesos do modelo guardados em 'gpt2-medium-ft-medio.pth'")
# Out:
# --- Avaliação Visual (3 exemplos) ---
#
# Abaixo está uma instrução que descreve uma tarefa. Escreva uma resposta que conclua a solicitação adequadamente.
#
# ### Instrução:
# Classifique o texto da notícia abaixo em uma das seguintes categorias: Mundo, Esportes, Negócios ou Ciência/Tecnologia.
#
# ### Entrada:
# New OSes, applications from PalmSource PalmSource has been busy lately, and has now announced updates to both of its OS lines as well as a new web browser and OTA installer.
#
# Correct response:
# >> Ciência/Tecnologia
#
# Model response:
# >> Ciência/Tecnologia
# -------------------------------------
# Abaixo está uma instrução que descreve uma tarefa. Escreva uma resposta que conclua a solicitação adequadamente.
#
# ### Instrução:
# Classifique o texto da notícia abaixo em uma das seguintes categorias: Mundo, Esportes, Negócios ou Ciência/Tecnologia.
#
# ### Entrada:
# Israel scales back Gaza offensive as Palestinians mark Ramadan JERUSALEM : Israel scaled back its vast operation in northern Gaza despite the deaths of four more Palestinians as tens of thousands of Muslims joined the first Friday prayers of Ramadan at Jerusalem #39;s Al Aqsa mosque.
#
# Correct response:
# >> Mundo
#
# Model response:
# >> Mundo
# -------------------------------------
# Abaixo está uma instrução que descreve uma tarefa. Escreva uma resposta que conclua a solicitação adequadamente.
#
# ### Instrução:
# Classifique o texto da notícia abaixo em uma das seguintes categorias: Mundo, Esportes, Negócios ou Ciência/Tecnologia.
#
# ### Entrada:
# American Express weighs lawsuit vs Visa, MasterCard SAN FRANCISCO (AFX) -- American Express said Monday that in light of the Supreme Court #39;s decision against Visa and MasterCard, it will seek partnerships with US banks.
#
# Correct response:
# >> Negócios
#
# Model response:
# >> Negócios
# -------------------------------------
#
# A gerar respostas FINE-TUNED para todo o conjunto de teste...
# 100%|██████████| 200/200 [01:43<00:00,  1.93it/s]
# Concluído! Dados guardados em 'instruction-data-with-response.json'
# Pesos do modelo guardados em 'gpt2-medium-ft-medio.pth'

# %% [markdown]
# ## 6. Setup do Juiz LLM: Liberação de Memória e Subida do Ollama
# Limpando a GPU e utilizando o Ollama local (Llama 3.2) para atuar como Juiz entre o modelo Baseline e o Fine-Tuned.

# %%
# !apt-get update -y
# !apt-get install -y zstd
# !curl -fsSL https://ollama.com/install.sh | sh
import subprocess
import time

# Inicia o servidor do Ollama em segundo plano
print("Iniciando o servidor Ollama...")
process = subprocess.Popen(["ollama", "serve"], stdout=subprocess.PIPE, stderr=subprocess.PIPE)

# Aguarda uns segundos para o servidor inicializar completamente
time.sleep(5)
print("Servidor Ollama rodando no background!")

# !ollama pull llama3.2
# Out:
# Reading package lists... Done
# E: Could not open lock file /var/lib/apt/lists/lock - open (13: Permission denied)
# E: Unable to lock directory /var/lib/apt/lists/
# W: Problem unlinking the file /var/cache/apt/pkgcache.bin - RemoveCaches (13: Permission denied)
# W: Problem unlinking the file /var/cache/apt/srcpkgcache.bin - RemoveCaches (13: Permission denied)
# E: Could not open lock file /var/lib/dpkg/lock-frontend - open (13: Permission denied)
# E: Unable to acquire the dpkg frontend lock (/var/lib/dpkg/lock-frontend), are you root?
# >>> Cleaning up old version at /usr/local/lib/ollama
# [sudo] password for orlandojunior:
# sudo: a password is required
# ^C
# Iniciando o servidor Ollama...
# Servidor Ollama rodando no background!
# ]11;?\pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 1.5 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 2.1 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   0% ▕                  ▏ 9.4 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  18 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   1% ▕                  ▏  24 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  36 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  48 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   2% ▕                  ▏  50 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   3% ▕                  ▏  63 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  77 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff:   4% ▕                  ▏  84 MB/2.0 GB   83 MB/s     23spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏  98 MB/2.0 GB   83 MB/s     22spulling manifest
# pulling dde5aa3fc5ff:   5% ▕                  ▏ 108 MB/2.0 GB   83 MB/s     22spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 113 MB/2.0 GB   83 MB/s     22spulling manifest
# pulling dde5aa3fc5ff:   6% ▕█                 ▏ 124 MB/2.0 GB   83 MB/s     22spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 136 MB/2.0 GB   83 MB/s     22spulling manifest
# pulling dde5aa3fc5ff:   7% ▕█                 ▏ 142 MB/2.0 GB   83 MB/s     22spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 157 MB/2.0 GB   83 MB/s     22spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 168 MB/2.0 GB   83 MB/s     22spulling manifest
# pulling dde5aa3fc5ff:   8% ▕█                 ▏ 171 MB/2.0 GB   83 MB/s     22spulling manifest
# pulling dde5aa3fc5ff:   9% ▕█                 ▏ 189 MB/2.0 GB   94 MB/s     19spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 202 MB/2.0 GB   94 MB/s     19spulling manifest
# pulling dde5aa3fc5ff:  10% ▕█                 ▏ 208 MB/2.0 GB   94 MB/s     19spulling manifest
# pulling dde5aa3fc5ff:  11% ▕█                 ▏ 220 MB/2.0 GB   94 MB/s     18spulling manifest
# pulling dde5aa3fc5ff:  11% ▕██                ▏ 231 MB/2.0 GB   94 MB/s     18spulling manifest
# pulling dde5aa3fc5ff:  12% ▕██                ▏ 238 MB/2.0 GB   94 MB/s     18spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 253 MB/2.0 GB   94 MB/s     18spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 265 MB/2.0 GB   94 MB/s     18spulling manifest
# pulling dde5aa3fc5ff:  13% ▕██                ▏ 272 MB/2.0 GB   94 MB/s     18spulling manifest
# pulling dde5aa3fc5ff:  14% ▕██                ▏ 285 MB/2.0 GB   94 MB/s     18spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 298 MB/2.0 GB   99 MB/s     17spulling manifest
# pulling dde5aa3fc5ff:  15% ▕██                ▏ 304 MB/2.0 GB   99 MB/s     17spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 315 MB/2.0 GB   99 MB/s     17spulling manifest
# pulling dde5aa3fc5ff:  16% ▕██                ▏ 327 MB/2.0 GB   99 MB/s     17spulling manifest
# pulling dde5aa3fc5ff:  17% ▕██                ▏ 335 MB/2.0 GB   99 MB/s     16spulling manifest
# pulling dde5aa3fc5ff:  17% ▕███               ▏ 347 MB/2.0 GB   99 MB/s     16spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 361 MB/2.0 GB   99 MB/s     16spulling manifest
# pulling dde5aa3fc5ff:  18% ▕███               ▏ 368 MB/2.0 GB   99 MB/s     16spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 380 MB/2.0 GB   99 MB/s     16spulling manifest
# pulling dde5aa3fc5ff:  19% ▕███               ▏ 393 MB/2.0 GB   99 MB/s     16spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 399 MB/2.0 GB   99 MB/s     16spulling manifest
# pulling dde5aa3fc5ff:  20% ▕███               ▏ 411 MB/2.0 GB  101 MB/s     15spulling manifest
# pulling dde5aa3fc5ff:  21% ▕███               ▏ 421 MB/2.0 GB  101 MB/s     15spulling manifest
# pulling dde5aa3fc5ff:  21% ▕███               ▏ 431 MB/2.0 GB  101 MB/s     15spulling manifest
# pulling dde5aa3fc5ff:  22% ▕███               ▏ 444 MB/2.0 GB  101 MB/s     15spulling manifest
# pulling dde5aa3fc5ff:  23% ▕████              ▏ 457 MB/2.0 GB  101 MB/s     15spulling manifest
# pulling dde5aa3fc5ff:  23% ▕████              ▏ 463 MB/2.0 GB  101 MB/s     15spulling manifest
# pulling dde5aa3fc5ff:  24% ▕████              ▏ 474 MB/2.0 GB  101 MB/s     15spulling manifest
# pulling dde5aa3fc5ff:  24% ▕████              ▏ 488 MB/2.0 GB  101 MB/s     15spulling manifest
# pulling dde5aa3fc5ff:  25% ▕████              ▏ 494 MB/2.0 GB  101 MB/s     15spulling manifest
# pulling dde5aa3fc5ff:  25% ▕████              ▏ 508 MB/2.0 GB  101 MB/s     14spulling manifest
# pulling dde5aa3fc5ff:  26% ▕████              ▏ 521 MB/2.0 GB  102 MB/s     14spulling manifest
# pulling dde5aa3fc5ff:  26% ▕████              ▏ 526 MB/2.0 GB  102 MB/s     14spulling manifest
# pulling dde5aa3fc5ff:  27% ▕████              ▏ 540 MB/2.0 GB  102 MB/s     14spulling manifest
# pulling dde5aa3fc5ff:  27% ▕████              ▏ 551 MB/2.0 GB  102 MB/s     14spulling manifest
# pulling dde5aa3fc5ff:  28% ▕████              ▏ 559 MB/2.0 GB  102 MB/s     14spulling manifest
# pulling dde5aa3fc5ff:  28% ▕█████             ▏ 570 MB/2.0 GB  102 MB/s     14spulling manifest
# pulling dde5aa3fc5ff:  29% ▕█████             ▏ 584 MB/2.0 GB  102 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  29% ▕█████             ▏ 589 MB/2.0 GB  102 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  30% ▕█████             ▏ 602 MB/2.0 GB  102 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  30% ▕█████             ▏ 615 MB/2.0 GB  102 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  31% ▕█████             ▏ 622 MB/2.0 GB  103 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  31% ▕█████             ▏ 635 MB/2.0 GB  103 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  32% ▕█████             ▏ 647 MB/2.0 GB  103 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  32% ▕█████             ▏ 653 MB/2.0 GB  103 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  33% ▕█████             ▏ 666 MB/2.0 GB  103 MB/s     13spulling manifest
# pulling dde5aa3fc5ff:  34% ▕██████            ▏ 678 MB/2.0 GB  103 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  34% ▕██████            ▏ 685 MB/2.0 GB  103 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  35% ▕██████            ▏ 700 MB/2.0 GB  103 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  35% ▕██████            ▏ 712 MB/2.0 GB  103 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  36% ▕██████            ▏ 717 MB/2.0 GB  103 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  36% ▕██████            ▏ 730 MB/2.0 GB  104 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  37% ▕██████            ▏ 742 MB/2.0 GB  104 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  37% ▕██████            ▏ 750 MB/2.0 GB  104 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  38% ▕██████            ▏ 762 MB/2.0 GB  104 MB/s     12spulling manifest
# pulling dde5aa3fc5ff:  38% ▕██████            ▏ 776 MB/2.0 GB  104 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  39% ▕██████            ▏ 782 MB/2.0 GB  104 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  39% ▕███████           ▏ 795 MB/2.0 GB  104 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  40% ▕███████           ▏ 808 MB/2.0 GB  104 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  40% ▕███████           ▏ 813 MB/2.0 GB  104 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  41% ▕███████           ▏ 827 MB/2.0 GB  104 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  42% ▕███████           ▏ 839 MB/2.0 GB  104 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  42% ▕███████           ▏ 845 MB/2.0 GB  104 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  43% ▕███████           ▏ 859 MB/2.0 GB  104 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  43% ▕███████           ▏ 869 MB/2.0 GB  104 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  43% ▕███████           ▏ 873 MB/2.0 GB  104 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  44% ▕███████           ▏ 880 MB/2.0 GB  104 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  44% ▕███████           ▏ 887 MB/2.0 GB  104 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  44% ▕███████           ▏ 889 MB/2.0 GB  104 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  44% ▕███████           ▏ 892 MB/2.0 GB  104 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  44% ▕███████           ▏ 896 MB/2.0 GB  104 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  45% ▕████████          ▏ 900 MB/2.0 GB  104 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  45% ▕████████          ▏ 909 MB/2.0 GB  100 MB/s     11spulling manifest
# pulling dde5aa3fc5ff:  46% ▕████████          ▏ 920 MB/2.0 GB  100 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  46% ▕████████          ▏ 927 MB/2.0 GB  100 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  47% ▕████████          ▏ 941 MB/2.0 GB  100 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  47% ▕████████          ▏ 953 MB/2.0 GB  100 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  47% ▕████████          ▏ 958 MB/2.0 GB  100 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  48% ▕████████          ▏ 972 MB/2.0 GB  100 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  49% ▕████████          ▏ 984 MB/2.0 GB  100 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  49% ▕████████          ▏ 989 MB/2.0 GB  100 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  50% ▕████████          ▏ 1.0 GB/2.0 GB  100 MB/s     10spulling manifest
# pulling dde5aa3fc5ff:  50% ▕█████████         ▏ 1.0 GB/2.0 GB  102 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  51% ▕█████████         ▏ 1.0 GB/2.0 GB  102 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  51% ▕█████████         ▏ 1.0 GB/2.0 GB  102 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  52% ▕█████████         ▏ 1.0 GB/2.0 GB  102 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  52% ▕█████████         ▏ 1.1 GB/2.0 GB  102 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  53% ▕█████████         ▏ 1.1 GB/2.0 GB  102 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  53% ▕█████████         ▏ 1.1 GB/2.0 GB  102 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  54% ▕█████████         ▏ 1.1 GB/2.0 GB  102 MB/s      9spulling manifest
# pulling dde5aa3fc5ff:  54% ▕█████████         ▏ 1.1 GB/2.0 GB  102 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  55% ▕█████████         ▏ 1.1 GB/2.0 GB  102 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  55% ▕█████████         ▏ 1.1 GB/2.0 GB  103 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  56% ▕██████████        ▏ 1.1 GB/2.0 GB  103 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  57% ▕██████████        ▏ 1.1 GB/2.0 GB  103 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  57% ▕██████████        ▏ 1.1 GB/2.0 GB  103 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  58% ▕██████████        ▏ 1.2 GB/2.0 GB  103 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  58% ▕██████████        ▏ 1.2 GB/2.0 GB  103 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  58% ▕██████████        ▏ 1.2 GB/2.0 GB  103 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  59% ▕██████████        ▏ 1.2 GB/2.0 GB  103 MB/s      8spulling manifest
# pulling dde5aa3fc5ff:  60% ▕██████████        ▏ 1.2 GB/2.0 GB  103 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  60% ▕██████████        ▏ 1.2 GB/2.0 GB  103 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  61% ▕██████████        ▏ 1.2 GB/2.0 GB  102 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  61% ▕███████████       ▏ 1.2 GB/2.0 GB  102 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  62% ▕███████████       ▏ 1.2 GB/2.0 GB  102 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  62% ▕███████████       ▏ 1.3 GB/2.0 GB  102 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  63% ▕███████████       ▏ 1.3 GB/2.0 GB  102 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  63% ▕███████████       ▏ 1.3 GB/2.0 GB  102 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  64% ▕███████████       ▏ 1.3 GB/2.0 GB  102 MB/s      7spulling manifest
# pulling dde5aa3fc5ff:  64% ▕███████████       ▏ 1.3 GB/2.0 GB  102 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  65% ▕███████████       ▏ 1.3 GB/2.0 GB  102 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  65% ▕███████████       ▏ 1.3 GB/2.0 GB  102 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  66% ▕███████████       ▏ 1.3 GB/2.0 GB  102 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  66% ▕███████████       ▏ 1.3 GB/2.0 GB  102 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  67% ▕████████████      ▏ 1.4 GB/2.0 GB  102 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  68% ▕████████████      ▏ 1.4 GB/2.0 GB  102 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  68% ▕████████████      ▏ 1.4 GB/2.0 GB  102 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  69% ▕████████████      ▏ 1.4 GB/2.0 GB  102 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  69% ▕████████████      ▏ 1.4 GB/2.0 GB  102 MB/s      6spulling manifest
# pulling dde5aa3fc5ff:  69% ▕████████████      ▏ 1.4 GB/2.0 GB  102 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  70% ▕████████████      ▏ 1.4 GB/2.0 GB  102 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  71% ▕████████████      ▏ 1.4 GB/2.0 GB  102 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  71% ▕████████████      ▏ 1.4 GB/2.0 GB  102 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  72% ▕████████████      ▏ 1.4 GB/2.0 GB  102 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  72% ▕█████████████     ▏ 1.5 GB/2.0 GB  102 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  73% ▕█████████████     ▏ 1.5 GB/2.0 GB  102 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  73% ▕█████████████     ▏ 1.5 GB/2.0 GB  102 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  74% ▕█████████████     ▏ 1.5 GB/2.0 GB  102 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  74% ▕█████████████     ▏ 1.5 GB/2.0 GB  102 MB/s      5spulling manifest
# pulling dde5aa3fc5ff:  75% ▕█████████████     ▏ 1.5 GB/2.0 GB  102 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  75% ▕█████████████     ▏ 1.5 GB/2.0 GB  102 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  76% ▕█████████████     ▏ 1.5 GB/2.0 GB  102 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  76% ▕█████████████     ▏ 1.5 GB/2.0 GB  102 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  77% ▕█████████████     ▏ 1.6 GB/2.0 GB  102 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  77% ▕█████████████     ▏ 1.6 GB/2.0 GB  102 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  78% ▕█████████████     ▏ 1.6 GB/2.0 GB  102 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  79% ▕██████████████    ▏ 1.6 GB/2.0 GB  102 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  79% ▕██████████████    ▏ 1.6 GB/2.0 GB  102 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  79% ▕██████████████    ▏ 1.6 GB/2.0 GB  102 MB/s      4spulling manifest
# pulling dde5aa3fc5ff:  80% ▕██████████████    ▏ 1.6 GB/2.0 GB  102 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  81% ▕██████████████    ▏ 1.6 GB/2.0 GB  102 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  81% ▕██████████████    ▏ 1.6 GB/2.0 GB  102 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  82% ▕██████████████    ▏ 1.7 GB/2.0 GB  102 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  82% ▕██████████████    ▏ 1.7 GB/2.0 GB  102 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  83% ▕██████████████    ▏ 1.7 GB/2.0 GB  102 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  83% ▕███████████████   ▏ 1.7 GB/2.0 GB  102 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  84% ▕███████████████   ▏ 1.7 GB/2.0 GB  102 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  84% ▕███████████████   ▏ 1.7 GB/2.0 GB  102 MB/s      3spulling manifest
# pulling dde5aa3fc5ff:  85% ▕███████████████   ▏ 1.7 GB/2.0 GB  102 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  85% ▕███████████████   ▏ 1.7 GB/2.0 GB  102 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  86% ▕███████████████   ▏ 1.7 GB/2.0 GB  102 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  87% ▕███████████████   ▏ 1.7 GB/2.0 GB  102 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  87% ▕███████████████   ▏ 1.8 GB/2.0 GB  102 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  87% ▕███████████████   ▏ 1.8 GB/2.0 GB  102 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  88% ▕███████████████   ▏ 1.8 GB/2.0 GB  102 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  88% ▕███████████████   ▏ 1.8 GB/2.0 GB  102 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  89% ▕████████████████  ▏ 1.8 GB/2.0 GB  102 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  90% ▕████████████████  ▏ 1.8 GB/2.0 GB  102 MB/s      2spulling manifest
# pulling dde5aa3fc5ff:  90% ▕████████████████  ▏ 1.8 GB/2.0 GB  102 MB/s      1spulling manifest
# pulling dde5aa3fc5ff:  90% ▕████████████████  ▏ 1.8 GB/2.0 GB  102 MB/s      1spulling manifest
# pulling dde5aa3fc5ff:  91% ▕████████████████  ▏ 1.8 GB/2.0 GB  102 MB/s      1spulling manifest
# pulling dde5aa3fc5ff:  91% ▕████████████████  ▏ 1.8 GB/2.0 GB  102 MB/s      1spulling manifest
# pulling dde5aa3fc5ff:  92% ▕████████████████  ▏ 1.9 GB/2.0 GB  102 MB/s      1spulling manifest
# pulling dde5aa3fc5ff:  93% ▕████████████████  ▏ 1.9 GB/2.0 GB  107 MB/s      1spulling manifest
# pulling dde5aa3fc5ff:  93% ▕████████████████  ▏ 1.9 GB/2.0 GB  107 MB/s      1spulling manifest
# pulling dde5aa3fc5ff:  94% ▕████████████████  ▏ 1.9 GB/2.0 GB  107 MB/s      1spulling manifest
# pulling dde5aa3fc5ff:  94% ▕████████████████  ▏ 1.9 GB/2.0 GB  107 MB/s      1spulling manifest
# pulling dde5aa3fc5ff:  94% ▕████████████████  ▏ 1.9 GB/2.0 GB  107 MB/s      1spulling manifest
# pulling dde5aa3fc5ff:  95% ▕█████████████████ ▏ 1.9 GB/2.0 GB  107 MB/s      1spulling manifest
# pulling dde5aa3fc5ff:  95% ▕█████████████████ ▏ 1.9 GB/2.0 GB  107 MB/s      0spulling manifest
# pulling dde5aa3fc5ff:  95% ▕█████████████████ ▏ 1.9 GB/2.0 GB  107 MB/s      0spulling manifest
# pulling dde5aa3fc5ff:  96% ▕█████████████████ ▏ 1.9 GB/2.0 GB  107 MB/s      0spulling manifest
# pulling dde5aa3fc5ff:  97% ▕█████████████████ ▏ 1.9 GB/2.0 GB  107 MB/s      0spulling manifest
# pulling dde5aa3fc5ff:  97% ▕█████████████████ ▏ 2.0 GB/2.0 GB  107 MB/s      0spulling manifest
# pulling dde5aa3fc5ff:  97% ▕█████████████████ ▏ 2.0 GB/2.0 GB  105 MB/s      0spulling manifest
# pulling dde5aa3fc5ff:  98% ▕█████████████████ ▏ 2.0 GB/2.0 GB  105 MB/s      0spulling manifest
# pulling dde5aa3fc5ff:  98% ▕█████████████████ ▏ 2.0 GB/2.0 GB  105 MB/s      0spulling manifest
# pulling dde5aa3fc5ff:  99% ▕█████████████████ ▏ 2.0 GB/2.0 GB  105 MB/s      0spulling manifest
# pulling dde5aa3fc5ff:  99% ▕█████████████████ ▏ 2.0 GB/2.0 GB  105 MB/s      0spulling manifest
# pulling dde5aa3fc5ff:  99% ▕█████████████████ ▏ 2.0 GB/2.0 GB  105 MB/s      0spulling manifest
# pulling dde5aa3fc5ff:  99% ▕█████████████████ ▏ 2.0 GB/2.0 GB  105 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB  105 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB  105 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕█████████████████ ▏ 2.0 GB/2.0 GB  105 MB/s      0spulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B                         pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠋ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠙ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠹ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠸ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠼ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠴ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠦ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠧ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠇ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠏ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠋ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠙ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠹ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠸ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠼ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠴ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠦ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠧ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠇ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest ⠏ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success

# %%
import psutil

def check_if_running(process_name):
    running = False
    for proc in psutil.process_iter(["name"]):
        if process_name in proc.info["name"]:
            running = True
            break
    return running

ollama_running = check_if_running("ollama")

if not ollama_running:
    raise RuntimeError("Ollama not running. Launch ollama before proceeding.")
print("Ollama running:", check_if_running("ollama"))
# Out:
# Ollama running: True

# %%
import os
import time

# O comando nohup força o processo a rodar no background sem travar o Colab
print("Iniciando o servidor Ollama em segundo plano...")
os.system("nohup ollama serve > ollama_server.log 2>&1 &")

time.sleep(5)

print("Servidor iniciado! Verificando os logs iniciais:")
# Exibe as primeiras linhas do log para confirmar que funcionou
# !cat ollama_server.log | head -n 5
# Out:
# Iniciando o servidor Ollama em segundo plano...
# Servidor iniciado! Verificando os logs iniciais:
# Error: listen tcp 127.0.0.1:11434: bind: address already in use

# %% [markdown]
# ## 7. Pipeline de Avaliação Final (LLM-as-a-Judge)

# %% [markdown]
# ## 7.1 Evaluating the finetuned LLM
# Nesta secção, utilizamos o LLM-as-a-Judge (Llama 3.2 via Ollama local) para avaliar comparativamente o Modelo BASE (A) e o Modelo FINE-TUNED (B), conforme exigido no laboratório.

# %%
import urllib.request
import json
import os
import time
import subprocess

# 1. Limpeza para evitar OOM (Out of Memory)
if 'model' in locals():
    del model
torch.cuda.empty_cache()

# 2. Iniciar o Ollama (adaptado para o Colab não falhar)
print("A iniciar o servidor Ollama...")
os.system("curl -fsSL https://ollama.com/install.sh | sh")
os.system("pkill ollama")
time.sleep(2)
subprocess.Popen(["ollama", "serve"], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
time.sleep(5)
print("A descarregar Llama 3.2...")
os.system("ollama pull llama3.2")

def query_model(prompt, model="llama3.2", url="http://127.0.0.1:11434/api/chat"):
    data = {
        "model": model,
        "messages": [
            {"role": "user", "content": prompt}
        ],
        "options": {
            "seed": 123,
            "temperature": 0,
            "num_ctx": 2048
        }
    }

    payload = json.dumps(data).encode("utf-8")

    request = urllib.request.Request(url, data=payload, method="POST")
    request.add_header("Content-Type", "application/json")

    response_data = ""
    with urllib.request.urlopen(request) as response:
        while True:
            line = response.readline().decode("utf-8")
            if not line:
                break
            response_json = json.loads(line)
            response_data += response_json["message"]["content"]

    return response_data

try:
    print("\nTeste de ligação:", query_model("Responda apenas 'OK'."))
except Exception as e:
    print(f"Erro na ligação ao Ollama: {e}")
# Out:
# A iniciar o servidor Ollama...
# >>> Cleaning up old version at /usr/local/lib/ollama
# sudo: a password is required
# pkill: killing pid 209 failed: Operation not permitted
# A descarregar Llama 3.2...
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest
# pulling dde5aa3fc5ff: 100% ▕██████████████████▏ 2.0 GB
# pulling 966de95ca8a6: 100% ▕██████████████████▏ 1.4 KB
# pulling fcc5a6bec9da: 100% ▕██████████████████▏ 7.7 KB
# pulling a70ff7e570d9: 100% ▕██████████████████▏ 6.0 KB
# pulling 56bb8bd477a5: 100% ▕██████████████████▏   96 B
# pulling 34bb5ab01051: 100% ▕██████████████████▏  561 B
# verifying sha256 digest
# writing manifest
# success
# Teste de ligação: OK.

# %% [markdown]
# ### Gerando as pontuações (Scoring)
# Criamos o *prompt* comparativo e avaliamos todas as entradas do conjunto de teste, extraindo as métricas utilizando expressões regulares (RegEx).

# %%
import re
import numpy as np
from tqdm import tqdm

prompt_template = """Você é um juiz imparcial avaliando dois modelos de Inteligência Artificial em uma tarefa de classificação de texto.

Instrução: {instrucao}
Entrada: {entrada}
Gabarito (Resposta Correta): {gabarito}

Resposta Modelo A (Base): {resp_a}
Resposta Modelo B (Fine-tuned): {resp_b}

Avalie os dois modelos dando uma nota inteira de 0 a 5 para:
1. Correção factual
2. Aderência à instrução
3. Clareza/utilidade

Responda ESTRITAMENTE neste formato:
Modelo A - Correção: [nota], Aderência: [nota], Clareza: [nota]
Modelo B - Correção: [nota], Aderência: [nota], Clareza: [nota]
Vencedor: [A, B ou Empate]
Justificativa: [breve justificativa]
"""

resultados_avaliacao = []
erros = 0

print("A avaliar entradas do conjunto de teste...")
for entry in tqdm(test_data, desc="Scoring entries"):
    prompt = prompt_template.format(
        instrucao=entry['instruction'],
        entrada=entry.get('input', ''),
        gabarito=entry['output'],
        resp_a=entry.get('model_base_response', ''),
        resp_b=entry.get('model_ft_medio_response', '')
    )

    try:
        judge_response = query_model(prompt)
        entry['judge_evaluation'] = judge_response
        resultados_avaliacao.append(entry)
    except Exception as e:
        erros += 1

print(f"\nAvaliações concluídas. Falhas de conexão: {erros}")
# Out:
# A avaliar entradas do conjunto de teste...
# Scoring entries: 100%|██████████| 200/200 [1:10:48<00:00, 21.24s/it]
# Avaliações concluídas. Falhas de conexão: 0

# %% [markdown]
# ### Calculando as Médias e Exportando os Resultados
# Processamos o texto gerado pelo Juiz para calcular as vitórias e as pontuações médias de cada modelo.

# %%
import re
import numpy as np
import json

vitorias = {'A': 0, 'B': 0, 'Empate': 0}
scores_A = {'Correcao': [], 'Aderencia': [], 'Clareza': []}
scores_B = {'Correcao': [], 'Aderencia': [], 'Clareza': []}

falhas_parse = 0

for entry in resultados_avaliacao:
    eval_text = entry.get('judge_evaluation', '')

    match_vencedor = re.search(r"Vencedor\s*[:\*]*\s*(?:Modelo\s*)?([A-Za-z]+)", eval_text, re.IGNORECASE)

    match_A = re.search(r"Modelo A.*?Corre[çc][ãa]o.*?(\d).*?Ader[êe]ncia.*?(\d).*?Clareza.*?(\d)", eval_text, re.IGNORECASE | re.DOTALL)
    match_B = re.search(r"Modelo B.*?Corre[çc][ãa]o.*?(\d).*?Ader[êe]ncia.*?(\d).*?Clareza.*?(\d)", eval_text, re.IGNORECASE | re.DOTALL)

    try:
        # Verifica o Vencedor
        if match_vencedor:
            v = match_vencedor.group(1).upper()
            if "A" in v: vitorias['A'] += 1
            elif "B" in v: vitorias['B'] += 1
            elif "EMP" in v or "TIE" in v: vitorias['Empate'] += 1
            else: vitorias['Empate'] += 1

        # Verifica as Notas
        if match_A and match_B:
            scores_A['Correcao'].append(int(match_A.group(1)))
            scores_A['Aderencia'].append(int(match_A.group(2)))
            scores_A['Clareza'].append(int(match_A.group(3)))

            scores_B['Correcao'].append(int(match_B.group(1)))
            scores_B['Aderencia'].append(int(match_B.group(2)))
            scores_B['Clareza'].append(int(match_B.group(3)))
        else:
            falhas_parse += 1

    except ValueError:
        falhas_parse += 1

# Impressão final ao estilo do Ch07
total_avaliacoes = len(scores_A['Correcao'])

print(f"Number of scores parsed successfully: {total_avaliacoes} of {len(test_data)}")
if falhas_parse > 0:
    print(f"Failed to parse {falhas_parse} evaluations due to formatting issues.")

if total_avaliacoes > 0:
    print("\n--- WIN RATES ---")
    print(f"Base Model (A) Wins:       {vitorias['A']} ({(vitorias['A']/total_avaliacoes)*100:.1f}%)")
    print(f"Fine-Tuned Model (B) Wins: {vitorias['B']} ({(vitorias['B']/total_avaliacoes)*100:.1f}%)")
    print(f"Ties (Empates):            {vitorias['Empate']} ({(vitorias['Empate']/total_avaliacoes)*100:.1f}%)")

    print("\n--- AVERAGE SCORES (0-5) ---")
    print("Base Model (A):")
    print(f"  Correção:  {np.mean(scores_A['Correcao']):.2f}")
    print(f"  Aderência: {np.mean(scores_A['Aderencia']):.2f}")
    print(f"  Clareza:   {np.mean(scores_A['Clareza']):.2f}")

    print("\nFine-Tuned Model (B):")
    print(f"  Correção:  {np.mean(scores_B['Correcao']):.2f}")
    print(f"  Aderência: {np.mean(scores_B['Aderencia']):.2f}")
    print(f"  Clareza:   {np.mean(scores_B['Clareza']):.2f}")

# Atualiza o JSON com os dados consolidados
with open("dataset_avaliado_final.json", "w", encoding='utf-8') as f:
    json.dump(resultados_avaliacao, f, ensure_ascii=False, indent=4)
# Out:
# Number of scores parsed successfully: 200 of 200
#
# --- WIN RATES ---
# Base Model (A) Wins:       7 (3.5%)
# Fine-Tuned Model (B) Wins: 190 (95.0%)
# Ties (Empates):            3 (1.5%)
#
# --- AVERAGE SCORES (0-5) ---
# Base Model (A):
#   Correção:  2.81
#   Aderência: 1.82
#   Clareza:   2.19
#
# Fine-Tuned Model (B):
#   Correção:  4.28
#   Aderência: 4.75
#   Clareza:   4.14

# %%
import re
from tqdm import tqdm

def generate_model_scores(json_data, json_key, model="llama3.2"):
    scores = []
    for entry in tqdm(json_data, desc=f"Scoring {json_key}"):
        # Prompt fiel ao original do livro, mas em português
        prompt = (
            f"Dada a entrada `{format_input(entry)}` "
            f"e a saída correta (gabarito) `{entry['output']}`, "
            f"avalie a resposta do modelo `{entry.get(json_key, '')}` "
            f"numa escala de 0 a 100, onde 100 é a nota máxima e 0 é a mínima. "
            f"Responda APENAS com o número inteiro, sem textos adicionais."
        )

        score_text = query_model(prompt, model)

        try:
            # Tenta a conversão direta igual ao livro
            score = int(score_text.strip())
            scores.append(score)
        except ValueError:
            match = re.search(r"(\d+)", score_text)
            if match:
                scores.append(int(match.group(1)))
            else:
                print(f"\nCould not convert score: {score_text}")
                continue

    return scores

print("--- AVALIAÇÃO DE 0 A 100 (Estilo Capítulo 7) ---")


scores_ft = generate_model_scores(test_data, "model_ft_medio_response")

print(f"\nResultados para o Modelo Fine-Tuned:")
print(f"Number of scores: {len(scores_ft)} of {len(test_data)}")
if len(scores_ft) > 0:
    print(f"Average score: {sum(scores_ft)/len(scores_ft):.2f}\n")
# Out:
# --- AVALIAÇÃO DE 0 A 100 (Estilo Capítulo 7) ---
# Scoring model_ft_medio_response: 100%|██████████| 200/200 [00:54<00:00,  3.66it/s]
# Resultados para o Modelo Fine-Tuned:
# Number of scores: 200 of 200
# Average score: 75.60
